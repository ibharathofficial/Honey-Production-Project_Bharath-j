# %% [markdown]
# # Parts-2

# %% [markdown]
# # 1. Import required libraries and read the dataset.

# %%
import pandas as pd


import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.style

# %%
data=pd.read_csv("F:/honeyproduction.csv")
data
# Out:
#     state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0      AL   16000.0           71   1136000.0    159000.0        0.72
# 1      AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2      AR   53000.0           65   3445000.0   1688000.0        0.59
# 3      CA  450000.0           83  37350000.0  12326000.0        0.62
# 4      CO   27000.0           72   1944000.0   1594000.0        0.70
# ..    ...       ...          ...         ...         ...         ...
# 621    VA    4000.0           41    164000.0     23000.0        3.77
# 622    WA   62000.0           41   2542000.0   1017000.0        2.38
# 623    WV    6000.0           48    288000.0     95000.0        2.91
# 624    WI   60000.0           69   4140000.0   1863000.0        2.05
# 625    WY   50000.0           51   2550000.0    459000.0        1.87
#
#       prodvalue  year
# 0      818000.0  1998
# 1     2112000.0  1998
# 2     2033000.0  1998
# 3    23157000.0  1998
# 4     1361000.0  1998
# ..          ...   ...
# 621    618000.0  2012
# 622   6050000.0  2012
# 623    838000.0  2012
# 624   8487000.0  2012
# 625   4769000.0  2012
#
# [626 rows x 8 columns]

# %% [markdown]
# # 2. Check the first few samples, shape, info of the data and try to familiarize yourself with different features

# %%
data.head(10)
# Out:
#   state    numcol  yieldpercol   totalprod      stocks  priceperlb  \
# 0    AL   16000.0           71   1136000.0    159000.0        0.72
# 1    AZ   55000.0           60   3300000.0   1485000.0        0.64
# 2    AR   53000.0           65   3445000.0   1688000.0        0.59
# 3    CA  450000.0           83  37350000.0  12326000.0        0.62
# 4    CO   27000.0           72   1944000.0   1594000.0        0.70
# 5    FL  230000.0           98  22540000.0   4508000.0        0.64
# 6    GA   75000.0           56   4200000.0    307000.0        0.69
# 7    HI    8000.0          118    944000.0     66000.0        0.77
# 8    ID  120000.0           50   6000000.0   2220000.0        0.65
# 9    IL    9000.0           71    639000.0    204000.0        1.19
#
#     prodvalue  year
# 0    818000.0  1998
# 1   2112000.0  1998
# 2   2033000.0  1998
# 3  23157000.0  1998
# 4   1361000.0  1998
# 5  14426000.0  1998
# 6   2898000.0  1998
# 7    727000.0  1998
# 8   3900000.0  1998
# 9    760000.0  1998

# %%
print(data.shape)
# Out:
# (626, 8)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   state        626 non-null    object
#  1   numcol       626 non-null    float64
#  2   yieldpercol  626 non-null    int64
#  3   totalprod    626 non-null    float64
#  4   stocks       626 non-null    float64
#  5   priceperlb   626 non-null    float64
#  6   prodvalue    626 non-null    float64
#  7   year         626 non-null    int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 39.2+ KB

# %% [markdown]
# # 3. Display the percentage distribution of the data in each year using the pie chart

# %%
year_distribution = data['totalprod'].groupby(data['year']).sum()
year_distribution.plot(kind='pie',figsize=(6,8), autopct='%1.1f%%')
plt.title=('Percentage Distribution of Honey Production by Year.')
plt.ylable=('')
plt.show()

# %% [markdown]
# # 4. Plot and Understand the distribution of the variable "price per lb" using displot, and write your findings.

# %%
sns.displot(data['priceperlb'])
plt.title('priceperlb vs frequency')
plt.xlabel('priceperlb')
plt.ylabel('frequency')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 sns.displot(data['priceperlb'])
# ----> 2 plt.title('priceperlb vs frequency')
#       3 plt.xlabel('priceperlb')
#       4 plt.ylabel('frequency')
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # 5. Plot and understand the relationship between the variables 'numcol' and 'prodval' through scatterplot, and write your findings.

# %%
x=data["numcol"]
y=data["prodvalue"]
plt.scatter(x,y)
plt.title("relatonship between number of colonies and production value")
plt.xlabel=("Number of Colonies")
plt.ylabel=("Production Values")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 4
#       2 y=data["prodvalue"]
#       3 plt.scatter(x,y)
# ----> 4 plt.title("relatonship between number of colonies and production value")
#       5 plt.xlabel=("Number of Colonies")
#       6 plt.ylabel=("Production Values")
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # 6. Plot and understand the relationship between categorical variable 'year' and a numerical variable 'prodvalue' through boxplot, and write your findings.

# %%
x=data['year']
y=data['prodvalue']
plt.figure(figsize=(5,5))
sns.boxplot(data=data, x=data['year'],y=data['prodvalue'])
plt.title("production value and year")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       3 plt.figure(figsize=(5,5))
#       4 sns.boxplot(data=data, x=data['year'],y=data['prodvalue'])
# ----> 5 plt.title("production value and year")
#
# TypeError: 'str' object is not callable

# %% [markdown]
# # 7. Visualize and understand the relationship between the multiple pairs of variables throughout different years using pairplot and add your inferences. (use columns 'numcol', 'yield percol', 'total prod', 'prodvalue','year')

# %%
columns_of_interest = ['numcol', 'yieldpercol', 'totalprod', 'prodvalue', 'year']
selected_data = data[columns_of_interest]
sns.pairplot(selected_data, hue='year')

plt.show()

# %% [markdown]
# # 8. Display the correlation values using a plot and add your inferences. (use columns 'numcol', 'yield percol','total prod', 'stocks', 'price per lb', 'prodvalue')

# %%
columns_of_interest = ['numcol', 'yieldpercol', 'totalprod', 'stocks', 'priceperlb', 'prodvalue']
selected_data = data[columns_of_interest]
correlation_matrix = selected_data.corr()
sns.heatmap(correlation_matrix, annot=True, cmap="RdYlGn")

plt.title("Correlation Matrix")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 6
#       3 correlation_matrix = selected_data.corr()
#       4 sns.heatmap(correlation_matrix, annot=True, cmap="RdYlGn")
# ----> 6 plt.title("Correlation Matrix")
#       7 plt.show()
#
# TypeError: 'str' object is not callable
